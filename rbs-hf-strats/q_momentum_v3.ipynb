# %% [markdown]
# End-to-End Summary of the Enhanced Momentum Strategy
#
# 1. Objective
#
#         The strategy seeks to capitalize on momentum by selecting the best-performing Dow Jones Industrial Average (DJIA) stocks based on historical returns. It employs risk management enhancements to improve robustness and reduce concentration risks while maintaining competitive returns.
#
# 2. Data
#
#         •	Universe: 30 Dow Jones components.
#         •	Benchmark: Dow Jones Industrial Average Index (^DJI).
#         •	Data Sources: Monthly adjusted closing prices from Yahoo Finance.
#         •	Returns: Monthly percentage changes calculated for each stock and the benchmark.
#
# 3. Core Strategy
#
#     Baseline: Equal-Weighted Momentum Strategy
#
#         •	Momentum Calculation:
#         •	Calculate rolling returns over a fixed 9-month window.
#         •	Select the top 3 stocks with the highest rolling returns.
#         •	Portfolio Construction:
#         •	Equally weight the selected stocks and rebalance monthly.
#         •	Performance Metrics:
#         •	Sharpe Ratio: Measures risk-adjusted returns.
#         •	Max Drawdown: Largest loss from a portfolio peak.
#         •	Annualized Return: Geometric mean of yearly returns.
#
# 4. Enhancements
#
#     A. Dynamic Momentum Window (Enhancement 1)
#
#         •	Rationale:
#         •	Momentum trends are sensitive to market volatility. Adjusting the rolling window dynamically ensures the strategy adapts to changing market conditions.
#         •	Implementation:
#         •	Use a shorter window (6 months) during high-volatility periods and a longer window (12 months) during low-volatility periods. A default 9-month window is used for moderate volatility.
#         •	Impact:
#         •	Improved Sharpe ratio and annualized returns compared to the baseline.
#         •	Reduced drawdowns during volatile market conditions.
#
#     B. Sector Diversification (Enhancement 2)
#
#         •	Rationale:
#         •	Concentration risk arises when the top 3 stocks come from the same sector. Diversification mitigates this risk, ensuring exposure to multiple sectors.
#         •	Implementation:
#         •	Use a predefined sector mapping to ensure the selected top 3 stocks are from different sectors.
#         •	Prioritize the highest-ranked stock in each sector.
#         •	Impact:
#         •	Slightly lower Sharpe ratio and returns due to reduced exposure to concentrated momentum, but improved risk control with reduced drawdowns.
#         •	More stable and diversified portfolio performance.
#
# 5. Final Strategy Workflow
#
#     Step 1: Data Preparation
#
#         •	Fetch historical price data for Dow Jones components and calculate monthly returns.
#         •	Resample prices to monthly frequency and forward-fill missing data.
#
#     Step 2: Rolling Momentum Calculation
#
#         •	Dynamically calculate rolling returns based on market volatility.
#         •	High Volatility: 6-month window.
#         •	Low Volatility: 12-month window.
#         •	Moderate Volatility: 9-month window.
#
#     Step 3: Stock Selection
#
#         •	Rank stocks by their rolling returns.
#         •	Ensure sector diversification by selecting one stock per sector (up to 3).
#
#     Step 4: Portfolio Construction
#
#         •	Equally weight the top 3 selected stocks.
#         •	Rebalance monthly based on updated rankings.
#
#     Step 5: Risk and Performance Analysis
#
#         •	Compare the portfolio against the DJI benchmark using:
#         •	Sharpe Ratio for risk-adjusted returns.
#         •	Max Drawdown to evaluate downside risk.
#         •	Annualized Return for overall performance.
#
# 6. Final Performance Summary
#
#         •	Dynamic Momentum Window:
#         •	Sharpe Ratio: 0.85 (higher risk-adjusted returns).
#         •	Max Drawdown: -41.89%.
#         •	Annualized Return: 15.91%.
#         •	Sector Diversification:
#         •	Sharpe Ratio: 0.71 (lower but stable returns).
#         •	Max Drawdown: -42.30%.
#         •	Annualized Return: 12.16% (slightly reduced but more robust).
#
# 7. Key Takeaways
#
#         •	The baseline strategy effectively captures momentum-driven gains but lacks risk controls.
#         •	Dynamic momentum adjustment ensures adaptability to market conditions and enhances risk-adjusted returns.
#         •	Sector diversification introduces stability by reducing concentration risk, making the strategy more robust for long-term use.
#         •	The strategy balances return maximization and risk management, offering a consistent, data-driven approach to momentum investing.

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Define tickers for Dow Jones components
tickers = ['AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM', 'CSCO', 'CVX', 'DIS', 'DOW',
           'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'JPM', 'KO', 'MCD', 'MMM',
           'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ', 'WBA', 'WMT']

# Download monthly adjusted close prices and calculate monthly returns
data = yf.download(tickers, start='2005-01-01')['Adj Close'].resample('M').last().pct_change() + 1

# Download Dow Jones Index (DJI) data for comparison
data['dji'] = yf.download('^DJI', start='2005-01-01')['Adj Close'].resample('M').last().pct_change() + 1

# Fill missing data in `data`
data = data.fillna(method='ffill')  # Forward-fill missing data

# Function to calculate rolling returns
def get_rolling_ret(data, n):
    return data.rolling(n, min_periods=n).apply(np.prod)

# Function to determine dynamic rolling window size based on volatility
def dynamic_window(date, threshold_high=0.02, threshold_low=0.01):
    market_volatility = data['dji'].pct_change().rolling(12).std().loc[date]
    if market_volatility > threshold_high:
        return 6  # High volatility -> shorter window
    elif market_volatility < threshold_low:
        return 12  # Low volatility -> longer window
    else:
        return 9  # Moderate volatility -> default window

# Calculate dynamic rolling returns for all dates in advance
ret_dynamic = pd.DataFrame(index=data.index, columns=data.columns)
for date in data.index:
    window = dynamic_window(date)
    rolling_ret = get_rolling_ret(data, window)
    ret_dynamic.loc[date] = rolling_ret.loc[date]

# Ensure ret_dynamic is numeric
ret_dynamic = ret_dynamic.astype(float).fillna(0)

# Function to get the top-performing stocks (based on dynamic rolling returns)
def get_top_dynamic(date):
    try:
        top_stocks = ret_dynamic.loc[date].nlargest(3).index
        return top_stocks
    except Exception as e:
        print(f"Error on {date}: {e}")
        return pd.Index([])

# Function to calculate portfolio returns for the selected top stocks
def portfolio_ret_dynamic(date):
    top_stocks = get_top_dynamic(date)
    if top_stocks.empty:  # Handle case where no top stocks are returned
        return 0
    portfolio = data.loc[date:, top_stocks][1:2]  # Use top stocks
    return portfolio.mean(axis=1).values[0]

# Initialize a 'returns_dynamic' column for the dynamic strategy
data['returns_dynamic'] = 1.00

# Calculate portfolio returns for each date
for i in range(1, len(data) - 1):
    data['returns_dynamic'][i] = portfolio_ret_dynamic(data.index[i])

# Sharpe Ratio Calculation
def calculate_sharpe_ratio(returns, risk_free_rate=0.0, periods_per_year=12):
    excess_returns = returns - risk_free_rate
    annualized_volatility = returns.std() * np.sqrt(periods_per_year)
    annualized_mean = returns.mean() * periods_per_year
    return annualized_mean / annualized_volatility

# Maximum Drawdown Calculation
def calculate_max_drawdown(cumulative_returns):
    cumulative_max = cumulative_returns.cummax()
    drawdown = cumulative_returns / cumulative_max - 1
    return drawdown.min()

# Annualized Return Calculation
def calculate_annualized_return(cumulative_returns, periods_per_year=12):
    total_return = cumulative_returns.iloc[-1] - 1
    n_years = len(cumulative_returns) / periods_per_year
    return (1 + total_return) ** (1 / n_years) - 1

# Convert cumulative returns to monthly returns for metrics
strategy_returns_dynamic = data['returns_dynamic'].cumprod().pct_change()
benchmark_returns = data['dji'].cumprod().pct_change()

# Calculate Sharpe Ratios
strategy_sharpe_dynamic = calculate_sharpe_ratio(strategy_returns_dynamic)
benchmark_sharpe = calculate_sharpe_ratio(benchmark_returns)

# Calculate Maximum Drawdowns
strategy_max_drawdown_dynamic = calculate_max_drawdown(data['returns_dynamic'].cumprod())
benchmark_max_drawdown = calculate_max_drawdown(data['dji'].cumprod())

# Calculate Annualized Returns
strategy_annualized_return_dynamic = calculate_annualized_return(data['returns_dynamic'].cumprod())
benchmark_annualized_return = calculate_annualized_return(data['dji'].cumprod())

# Print metrics for strategy and benchmark
print(f"Strategy Sharpe Ratio (Dynamic): {strategy_sharpe_dynamic:.2f}")
print(f"Benchmark Sharpe Ratio: {benchmark_sharpe:.2f}")
print(f"Strategy Max Drawdown (Dynamic): {strategy_max_drawdown_dynamic:.2%}")
print(f"Benchmark Max Drawdown: {benchmark_max_drawdown:.2%}")
print(f"Strategy Annualized Return (Dynamic): {strategy_annualized_return_dynamic:.2%}")
print(f"Benchmark Annualized Return: {benchmark_annualized_return:.2%}")

# Plot cumulative returns for strategy and benchmark
plt.figure(figsize=[11, 8])
plt.plot(data['dji'].cumprod(), label='DJI')
plt.plot(data['returns_dynamic'].cumprod(), label='TIMING (Dynamic)')
plt.yscale('log')
plt.title('DJI Total Returns vs Strategies (2005-2024) - Log Scale')
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  30 of 30 completed
# [*********************100%***********************]  1 of 1 completed
# Strategy Sharpe Ratio (Dynamic): 0.85
# Benchmark Sharpe Ratio: 0.57
# Strategy Max Drawdown (Dynamic): -41.89%
# Benchmark Max Drawdown: -49.30%
# Strategy Annualized Return (Dynamic): 15.91%
# Benchmark Annualized Return: 7.50%

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Define tickers for Dow Jones components
tickers = ['AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM', 'CSCO', 'CVX', 'DIS', 'DOW',
           'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'JPM', 'KO', 'MCD', 'MMM',
           'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ', 'WBA', 'WMT']

# Sector mapping for Dow Jones components
sectors = {
    'AAPL': 'Technology', 'AMGN': 'Healthcare', 'AXP': 'Financials', 'BA': 'Industrials',
    'CAT': 'Industrials', 'CRM': 'Technology', 'CSCO': 'Technology', 'CVX': 'Energy',
    'DIS': 'Communication Services', 'DOW': 'Materials', 'GS': 'Financials',
    'HD': 'Consumer Discretionary', 'HON': 'Industrials', 'IBM': 'Technology',
    'INTC': 'Technology', 'JNJ': 'Healthcare', 'JPM': 'Financials', 'KO': 'Consumer Staples',
    'MCD': 'Consumer Discretionary', 'MMM': 'Industrials', 'MRK': 'Healthcare',
    'MSFT': 'Technology', 'NKE': 'Consumer Discretionary', 'PG': 'Consumer Staples',
    'TRV': 'Financials', 'UNH': 'Healthcare', 'V': 'Financials', 'VZ': 'Communication Services',
    'WBA': 'Consumer Staples', 'WMT': 'Consumer Staples'
}

# Download monthly adjusted close prices and calculate monthly returns
data = yf.download(tickers, start='2005-01-01')['Adj Close'].resample('M').last().pct_change() + 1

# Download Dow Jones Index (DJI) data for comparison
data['dji'] = yf.download('^DJI', start='2005-01-01')['Adj Close'].resample('M').last().pct_change() + 1

# Fill missing data in `data`
data = data.fillna(method='ffill')

# Function to calculate rolling returns
def get_rolling_ret(data, n):
    return data.rolling(n, min_periods=n).apply(np.prod)

# Function to determine dynamic rolling window size based on volatility
def dynamic_window(date, threshold_high=0.02, threshold_low=0.01):
    market_volatility = data['dji'].pct_change().rolling(12).std().loc[date]
    if market_volatility > threshold_high:
        return 6  # High volatility -> shorter window
    elif market_volatility < threshold_low:
        return 12  # Low volatility -> longer window
    else:
        return 9  # Moderate volatility -> default window

# Calculate dynamic rolling returns for all dates in advance
ret_dynamic = pd.DataFrame(index=data.index, columns=data.columns)
for date in data.index:
    window = dynamic_window(date)
    rolling_ret = get_rolling_ret(data, window)
    ret_dynamic.loc[date] = rolling_ret.loc[date]

# Ensure ret_dynamic is numeric
ret_dynamic = ret_dynamic.astype(float).fillna(0)

# Function to get top-performing stocks with sector diversification
def get_top_diversified(date):
    try:
        top_stocks = ret_dynamic.loc[date].nlargest(len(ret_dynamic.columns)).index
        selected_stocks = []
        seen_sectors = set()
        for stock in top_stocks:
            sector = sectors.get(stock, None)
            if sector not in seen_sectors:
                selected_stocks.append(stock)
                seen_sectors.add(sector)
            if len(selected_stocks) == 3:
                break
        return pd.Index(selected_stocks)
    except Exception as e:
        print(f"Error on {date}: {e}")
        return pd.Index([])

# Function to calculate portfolio returns for diversified stocks
def portfolio_ret_diversified(date):
    top_stocks = get_top_diversified(date)
    if top_stocks.empty:  # Handle case where no top stocks are returned
        return 0
    portfolio = data.loc[date:, top_stocks][1:2]  # Use top stocks
    return portfolio.mean(axis=1).values[0]

# Initialize a 'returns_diversified' column for the diversified strategy
data['returns_diversified'] = 1.00

# Calculate portfolio returns for each date
for i in range(1, len(data) - 1):
    data['returns_diversified'][i] = portfolio_ret_diversified(data.index[i])

# Sharpe Ratio Calculation
def calculate_sharpe_ratio(returns, risk_free_rate=0.0, periods_per_year=12):
    excess_returns = returns - risk_free_rate
    annualized_volatility = returns.std() * np.sqrt(periods_per_year)
    annualized_mean = returns.mean() * periods_per_year
    return annualized_mean / annualized_volatility

# Maximum Drawdown Calculation
def calculate_max_drawdown(cumulative_returns):
    cumulative_max = cumulative_returns.cummax()
    drawdown = cumulative_returns / cumulative_max - 1
    return drawdown.min()

# Annualized Return Calculation
def calculate_annualized_return(cumulative_returns, periods_per_year=12):
    total_return = cumulative_returns.iloc[-1] - 1
    n_years = len(cumulative_returns) / periods_per_year
    return (1 + total_return) ** (1 / n_years) - 1

# Convert cumulative returns to monthly returns for metrics
strategy_returns_diversified = data['returns_diversified'].cumprod().pct_change()
benchmark_returns = data['dji'].cumprod().pct_change()

# Calculate Sharpe Ratios
strategy_sharpe_diversified = calculate_sharpe_ratio(strategy_returns_diversified)
benchmark_sharpe = calculate_sharpe_ratio(benchmark_returns)

# Calculate Maximum Drawdowns
strategy_max_drawdown_diversified = calculate_max_drawdown(data['returns_diversified'].cumprod())
benchmark_max_drawdown = calculate_max_drawdown(data['dji'].cumprod())

# Calculate Annualized Returns
strategy_annualized_return_diversified = calculate_annualized_return(data['returns_diversified'].cumprod())
benchmark_annualized_return = calculate_annualized_return(data['dji'].cumprod())

# Print metrics for strategy and benchmark
print(f"Strategy Sharpe Ratio (Diversified): {strategy_sharpe_diversified:.2f}")
print(f"Benchmark Sharpe Ratio: {benchmark_sharpe:.2f}")
print(f"Strategy Max Drawdown (Diversified): {strategy_max_drawdown_diversified:.2%}")
print(f"Benchmark Max Drawdown: {benchmark_max_drawdown:.2%}")
print(f"Strategy Annualized Return (Diversified): {strategy_annualized_return_diversified:.2%}")
print(f"Benchmark Annualized Return: {benchmark_annualized_return:.2%}")

# Plot cumulative returns for strategy and benchmark
plt.figure(figsize=[11, 8])
plt.plot(data['dji'].cumprod(), label='DJI')
plt.plot(data['returns_diversified'].cumprod(), label='TIMING (Diversified)')
plt.yscale('log')
plt.title('DJI Total Returns vs Strategies (2005-2024) - Log Scale')
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  30 of 30 completed
# [*********************100%***********************]  1 of 1 completed
# Strategy Sharpe Ratio (Diversified): 0.71
# Benchmark Sharpe Ratio: 0.57
# Strategy Max Drawdown (Diversified): -42.30%
# Benchmark Max Drawdown: -49.30%
# Strategy Annualized Return (Diversified): 12.16%
# Benchmark Annualized Return: 7.50%

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Define tickers for Dow Jones components
tickers = ['AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM', 'CSCO', 'CVX', 'DIS', 'DOW',
           'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'JPM', 'KO', 'MCD', 'MMM',
           'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ', 'WBA', 'WMT']

# Sector mapping for Dow Jones components
sectors = {
    'AAPL': 'Technology', 'AMGN': 'Healthcare', 'AXP': 'Financials', 'BA': 'Industrials',
    'CAT': 'Industrials', 'CRM': 'Technology', 'CSCO': 'Technology', 'CVX': 'Energy',
    'DIS': 'Communication Services', 'DOW': 'Materials', 'GS': 'Financials',
    'HD': 'Consumer Discretionary', 'HON': 'Industrials', 'IBM': 'Technology',
    'INTC': 'Technology', 'JNJ': 'Healthcare', 'JPM': 'Financials', 'KO': 'Consumer Staples',
    'MCD': 'Consumer Discretionary', 'MMM': 'Industrials', 'MRK': 'Healthcare',
    'MSFT': 'Technology', 'NKE': 'Consumer Discretionary', 'PG': 'Consumer Staples',
    'TRV': 'Financials', 'UNH': 'Healthcare', 'V': 'Financials', 'VZ': 'Communication Services',
    'WBA': 'Consumer Staples', 'WMT': 'Consumer Staples'
}

# Download monthly adjusted close prices and calculate monthly returns
data = yf.download(tickers, start='2005-01-01')['Adj Close'].resample('M').last()
returns = data.pct_change()

# Download Dow Jones Index (DJI) data for comparison
dji_data = yf.download('^DJI', start='2005-01-01')['Adj Close'].resample('M').last()
returns['dji'] = dji_data.pct_change()

# Fill missing data in `returns`
returns = returns.fillna(method='ffill')

# Dynamic window function
def dynamic_window(date, threshold_high=0.02, threshold_low=0.01):
    """Determine rolling window size based on market volatility."""
    try:
        market_volatility = returns['dji'].rolling(12).std().loc[date]
        if market_volatility > threshold_high:
            return 6  # High volatility -> shorter window
        elif market_volatility < threshold_low:
            return 12  # Low volatility -> longer window
        else:
            return 9  # Moderate volatility -> default window
    except KeyError:
        return 9  # Default fallback

# Factor-based scoring function
def get_top_dynamic_multi_factor_stocks(date, num_stocks=3):
    """Select top stocks based on momentum and mean-reversion factors."""
    try:
        window = dynamic_window(date)
        # Momentum: Returns over dynamic window
        momentum = returns.iloc[:date].pct_change(window).iloc[-1]
        # Mean-reversion: Short-term negative returns
        mean_reversion = -returns.iloc[:date].pct_change(1).iloc[-1]
        # Combined score
        scores = 0.5 * momentum + 0.5 * mean_reversion
        scores = scores.dropna()

        # Sector diversification
        top_stocks = scores.nlargest(len(scores)).index
        selected_stocks = []
        seen_sectors = set()
        for stock in top_stocks:
            sector = sectors.get(stock, None)
            if sector not in seen_sectors:
                selected_stocks.append(stock)
                seen_sectors.add(sector)
            if len(selected_stocks) == num_stocks:
                break
        return pd.Index(selected_stocks)
    except Exception as e:
        print(f"Error on {date}: {e}")
        return pd.Index([])

# Portfolio returns calculation
def portfolio_ret_dynamic_multi_factor(date):
    """Calculate portfolio return for the selected stocks."""
    try:
        top_stocks = get_top_dynamic_multi_factor_stocks(date)
        if top_stocks.empty:
            return 0
        # Calculate equal-weighted portfolio returns
        portfolio = returns.loc[date, top_stocks]
        return portfolio.mean()
    except Exception as e:
        print(f"Error on {date}: {e}")
        return 0

# Initialize a 'returns_dynamic_multi_factor' column for the new strategy
returns['returns_dynamic_multi_factor'] = 1.00

# Calculate portfolio returns for each date
for i in range(1, len(returns) - 1):
    returns['returns_dynamic_multi_factor'].iloc[i] = portfolio_ret_dynamic_multi_factor(returns.index[i])

# Sharpe Ratio Calculation
def calculate_sharpe_ratio(returns, risk_free_rate=0.0, periods_per_year=12):
    excess_returns = returns - risk_free_rate
    annualized_volatility = returns.std() * np.sqrt(periods_per_year)
    annualized_mean = returns.mean() * periods_per_year
    return annualized_mean / annualized_volatility

# Maximum Drawdown Calculation
def calculate_max_drawdown(cumulative_returns):
    cumulative_max = cumulative_returns.cummax()
    drawdown = cumulative_returns / cumulative_max - 1
    return drawdown.min()

# Annualized Return Calculation
def calculate_annualized_return(cumulative_returns, periods_per_year=12):
    total_return = cumulative_returns.iloc[-1] - 1
    n_years = len(cumulative_returns) / periods_per_year
    return (1 + total_return) ** (1 / n_years) - 1

# Convert cumulative returns to monthly returns for metrics
strategy_returns_dynamic_multi_factor = returns['returns_dynamic_multi_factor'].cumprod().pct_change()
benchmark_returns = returns['dji'].cumprod().pct_change()

# Calculate Sharpe Ratios
strategy_sharpe_dynamic_multi_factor = calculate_sharpe_ratio(strategy_returns_dynamic_multi_factor)
benchmark_sharpe = calculate_sharpe_ratio(benchmark_returns)

# Calculate Maximum Drawdowns
strategy_max_drawdown_dynamic_multi_factor = calculate_max_drawdown(returns['returns_dynamic_multi_factor'].cumprod())
benchmark_max_drawdown = calculate_max_drawdown(returns['dji'].cumprod())

# Calculate Annualized Returns
strategy_annualized_return_dynamic_multi_factor = calculate_annualized_return(returns['returns_dynamic_multi_factor'].cumprod())
benchmark_annualized_return = calculate_annualized_return(returns['dji'].cumprod())

# Print metrics for strategy and benchmark
print(f"Strategy Sharpe Ratio (Dynamic Multi-Factor): {strategy_sharpe_dynamic_multi_factor:.2f}")
print(f"Benchmark Sharpe Ratio: {benchmark_sharpe:.2f}")
print(f"Strategy Max Drawdown (Dynamic Multi-Factor): {strategy_max_drawdown_dynamic_multi_factor:.2%}")
print(f"Benchmark Max Drawdown: {benchmark_max_drawdown:.2%}")
print(f"Strategy Annualized Return (Dynamic Multi-Factor): {strategy_annualized_return_dynamic_multi_factor:.2%}")
print(f"Benchmark Annualized Return: {benchmark_annualized_return:.2%}")

# Plot cumulative returns for strategy and benchmark
plt.figure(figsize=[11, 8])
plt.plot(returns['dji'].cumprod(), label='DJI')
plt.plot(returns['returns_dynamic_multi_factor'].cumprod(), label='Dynamic Multi-Factor Strategy')
plt.yscale('log')
plt.title('DJI Total Returns vs Strategies (2005-2024) - Log Scale')
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  30 of 30 completed
# [*********************100%***********************]  1 of 1 completed
# Error on 2005-02-28 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2005-02-28 00:00:00+00:00] of type Timestamp
# Error on 2005-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2005-03-31 00:00:00+00:00] of type Timestamp
# Error on 2005-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2005-04-30 00:00:00+00:00] of type Timestamp
# Error on 2005-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2005-05-31 00:00:00+00:00] of type Timestamp
# Error on 2005-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2005-06-30 00:00:00+00:00] of type Timestamp
# Error on 2005-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2005-07-31 00:00:00+00:00] of type Timestamp
# Error on 2005-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2005-08-31 00:00:00+00:00] of type Timestamp
# Error on 2005-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2005-09-30 00:00:00+00:00] of type Timestamp
# Error on 2005-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2005-10-31 00:00:00+00:00] of type Timestamp
# Error on 2005-11-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2005-11-30 00:00:00+00:00] of type Timestamp
# Error on 2005-12-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2005-12-31 00:00:00+00:00] of type Timestamp
# Error on 2006-01-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2006-01-31 00:00:00+00:00] of type Timestamp
# Error on 2006-02-28 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2006-02-28 00:00:00+00:00] of type Timestamp
# Error on 2006-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2006-03-31 00:00:00+00:00] of type Timestamp
# Error on 2006-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2006-04-30 00:00:00+00:00] of type Timestamp
# Error on 2006-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2006-05-31 00:00:00+00:00] of type Timestamp
# Error on 2006-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2006-06-30 00:00:00+00:00] of type Timestamp
# Error on 2006-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2006-07-31 00:00:00+00:00] of type Timestamp
# Error on 2006-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2006-08-31 00:00:00+00:00] of type Timestamp
# Error on 2006-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2006-09-30 00:00:00+00:00] of type Timestamp
# Error on 2006-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2006-10-31 00:00:00+00:00] of type Timestamp
# Error on 2006-11-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2006-11-30 00:00:00+00:00] of type Timestamp
# Error on 2006-12-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2006-12-31 00:00:00+00:00] of type Timestamp
# Error on 2007-01-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2007-01-31 00:00:00+00:00] of type Timestamp
# Error on 2007-02-28 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2007-02-28 00:00:00+00:00] of type Timestamp
# Error on 2007-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2007-03-31 00:00:00+00:00] of type Timestamp
# Error on 2007-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2007-04-30 00:00:00+00:00] of type Timestamp
# Error on 2007-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2007-05-31 00:00:00+00:00] of type Timestamp
# Error on 2007-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2007-06-30 00:00:00+00:00] of type Timestamp
# Error on 2007-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2007-07-31 00:00:00+00:00] of type Timestamp
# Error on 2007-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2007-08-31 00:00:00+00:00] of type Timestamp
# Error on 2007-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2007-09-30 00:00:00+00:00] of type Timestamp
# Error on 2007-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2007-10-31 00:00:00+00:00] of type Timestamp
# Error on 2007-11-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2007-11-30 00:00:00+00:00] of type Timestamp
# Error on 2007-12-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2007-12-31 00:00:00+00:00] of type Timestamp
# Error on 2008-01-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2008-01-31 00:00:00+00:00] of type Timestamp
# Error on 2008-02-29 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2008-02-29 00:00:00+00:00] of type Timestamp
# Error on 2008-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2008-03-31 00:00:00+00:00] of type Timestamp
# Error on 2008-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2008-04-30 00:00:00+00:00] of type Timestamp
# Error on 2008-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2008-05-31 00:00:00+00:00] of type Timestamp
# Error on 2008-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2008-06-30 00:00:00+00:00] of type Timestamp
# Error on 2008-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2008-07-31 00:00:00+00:00] of type Timestamp
# Error on 2008-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2008-08-31 00:00:00+00:00] of type Timestamp
# Error on 2008-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2008-09-30 00:00:00+00:00] of type Timestamp
# Error on 2008-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2008-10-31 00:00:00+00:00] of type Timestamp
# Error on 2008-11-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2008-11-30 00:00:00+00:00] of type Timestamp
# Error on 2008-12-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2008-12-31 00:00:00+00:00] of type Timestamp
# Error on 2009-01-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2009-01-31 00:00:00+00:00] of type Timestamp
# Error on 2009-02-28 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2009-02-28 00:00:00+00:00] of type Timestamp
# Error on 2009-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2009-03-31 00:00:00+00:00] of type Timestamp
# Error on 2009-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2009-04-30 00:00:00+00:00] of type Timestamp
# Error on 2009-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2009-05-31 00:00:00+00:00] of type Timestamp
# Error on 2009-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2009-06-30 00:00:00+00:00] of type Timestamp
# Error on 2009-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2009-07-31 00:00:00+00:00] of type Timestamp
# Error on 2009-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2009-08-31 00:00:00+00:00] of type Timestamp
# Error on 2009-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2009-09-30 00:00:00+00:00] of type Timestamp
# Error on 2009-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2009-10-31 00:00:00+00:00] of type Timestamp
# Error on 2009-11-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2009-11-30 00:00:00+00:00] of type Timestamp
# Error on 2009-12-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2009-12-31 00:00:00+00:00] of type Timestamp
# Error on 2010-01-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2010-01-31 00:00:00+00:00] of type Timestamp
# Error on 2010-02-28 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2010-02-28 00:00:00+00:00] of type Timestamp
# Error on 2010-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2010-03-31 00:00:00+00:00] of type Timestamp
# Error on 2010-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2010-04-30 00:00:00+00:00] of type Timestamp
# Error on 2010-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2010-05-31 00:00:00+00:00] of type Timestamp
# Error on 2010-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2010-06-30 00:00:00+00:00] of type Timestamp
# Error on 2010-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2010-07-31 00:00:00+00:00] of type Timestamp
# Error on 2010-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2010-08-31 00:00:00+00:00] of type Timestamp
# Error on 2010-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2010-09-30 00:00:00+00:00] of type Timestamp
# Error on 2010-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2010-10-31 00:00:00+00:00] of type Timestamp
# Error on 2010-11-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2010-11-30 00:00:00+00:00] of type Timestamp
# Error on 2010-12-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2010-12-31 00:00:00+00:00] of type Timestamp
# Error on 2011-01-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2011-01-31 00:00:00+00:00] of type Timestamp
# Error on 2011-02-28 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2011-02-28 00:00:00+00:00] of type Timestamp
# Error on 2011-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2011-03-31 00:00:00+00:00] of type Timestamp
# Error on 2011-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2011-04-30 00:00:00+00:00] of type Timestamp
# Error on 2011-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2011-05-31 00:00:00+00:00] of type Timestamp
# Error on 2011-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2011-06-30 00:00:00+00:00] of type Timestamp
# Error on 2011-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2011-07-31 00:00:00+00:00] of type Timestamp
# Error on 2011-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2011-08-31 00:00:00+00:00] of type Timestamp
# Error on 2011-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2011-09-30 00:00:00+00:00] of type Timestamp
# Error on 2011-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2011-10-31 00:00:00+00:00] of type Timestamp
# Error on 2011-11-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2011-11-30 00:00:00+00:00] of type Timestamp
# Error on 2011-12-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2011-12-31 00:00:00+00:00] of type Timestamp
# Error on 2012-01-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2012-01-31 00:00:00+00:00] of type Timestamp
# Error on 2012-02-29 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2012-02-29 00:00:00+00:00] of type Timestamp
# Error on 2012-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2012-03-31 00:00:00+00:00] of type Timestamp
# Error on 2012-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2012-04-30 00:00:00+00:00] of type Timestamp
# Error on 2012-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2012-05-31 00:00:00+00:00] of type Timestamp
# Error on 2012-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2012-06-30 00:00:00+00:00] of type Timestamp
# Error on 2012-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2012-07-31 00:00:00+00:00] of type Timestamp
# Error on 2012-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2012-08-31 00:00:00+00:00] of type Timestamp
# Error on 2012-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2012-09-30 00:00:00+00:00] of type Timestamp
# Error on 2012-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2012-10-31 00:00:00+00:00] of type Timestamp
# Error on 2012-11-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2012-11-30 00:00:00+00:00] of type Timestamp
# Error on 2012-12-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2012-12-31 00:00:00+00:00] of type Timestamp
# Error on 2013-01-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2013-01-31 00:00:00+00:00] of type Timestamp
# Error on 2013-02-28 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2013-02-28 00:00:00+00:00] of type Timestamp
# Error on 2013-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2013-03-31 00:00:00+00:00] of type Timestamp
# Error on 2013-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2013-04-30 00:00:00+00:00] of type Timestamp
# Error on 2013-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2013-05-31 00:00:00+00:00] of type Timestamp
# Error on 2013-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2013-06-30 00:00:00+00:00] of type Timestamp
# Error on 2013-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2013-07-31 00:00:00+00:00] of type Timestamp
# Error on 2013-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2013-08-31 00:00:00+00:00] of type Timestamp
# Error on 2013-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2013-09-30 00:00:00+00:00] of type Timestamp
# Error on 2013-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2013-10-31 00:00:00+00:00] of type Timestamp
# Error on 2013-11-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2013-11-30 00:00:00+00:00] of type Timestamp
# Error on 2013-12-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2013-12-31 00:00:00+00:00] of type Timestamp
# Error on 2014-01-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2014-01-31 00:00:00+00:00] of type Timestamp
# Error on 2014-02-28 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2014-02-28 00:00:00+00:00] of type Timestamp
# Error on 2014-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2014-03-31 00:00:00+00:00] of type Timestamp
# Error on 2014-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2014-04-30 00:00:00+00:00] of type Timestamp
# Error on 2014-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2014-05-31 00:00:00+00:00] of type Timestamp
# Error on 2014-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2014-06-30 00:00:00+00:00] of type Timestamp
# Error on 2014-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2014-07-31 00:00:00+00:00] of type Timestamp
# Error on 2014-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2014-08-31 00:00:00+00:00] of type Timestamp
# Error on 2014-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2014-09-30 00:00:00+00:00] of type Timestamp
# Error on 2014-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2014-10-31 00:00:00+00:00] of type Timestamp
# Error on 2014-11-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2014-11-30 00:00:00+00:00] of type Timestamp
# Error on 2014-12-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2014-12-31 00:00:00+00:00] of type Timestamp
# Error on 2015-01-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2015-01-31 00:00:00+00:00] of type Timestamp
# Error on 2015-02-28 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2015-02-28 00:00:00+00:00] of type Timestamp
# Error on 2015-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2015-03-31 00:00:00+00:00] of type Timestamp
# Error on 2015-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2015-04-30 00:00:00+00:00] of type Timestamp
# Error on 2015-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2015-05-31 00:00:00+00:00] of type Timestamp
# Error on 2015-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2015-06-30 00:00:00+00:00] of type Timestamp
# Error on 2015-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2015-07-31 00:00:00+00:00] of type Timestamp
# Error on 2015-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2015-08-31 00:00:00+00:00] of type Timestamp
# Error on 2015-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2015-09-30 00:00:00+00:00] of type Timestamp
# Error on 2015-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2015-10-31 00:00:00+00:00] of type Timestamp
# Error on 2015-11-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2015-11-30 00:00:00+00:00] of type Timestamp
# Error on 2015-12-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2015-12-31 00:00:00+00:00] of type Timestamp
# Error on 2016-01-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2016-01-31 00:00:00+00:00] of type Timestamp
# Error on 2016-02-29 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2016-02-29 00:00:00+00:00] of type Timestamp
# Error on 2016-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2016-03-31 00:00:00+00:00] of type Timestamp
# Error on 2016-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2016-04-30 00:00:00+00:00] of type Timestamp
# Error on 2016-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2016-05-31 00:00:00+00:00] of type Timestamp
# Error on 2016-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2016-06-30 00:00:00+00:00] of type Timestamp
# Error on 2016-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2016-07-31 00:00:00+00:00] of type Timestamp
# Error on 2016-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2016-08-31 00:00:00+00:00] of type Timestamp
# Error on 2016-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2016-09-30 00:00:00+00:00] of type Timestamp
# Error on 2016-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2016-10-31 00:00:00+00:00] of type Timestamp
# Error on 2016-11-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2016-11-30 00:00:00+00:00] of type Timestamp
# Error on 2016-12-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2016-12-31 00:00:00+00:00] of type Timestamp
# Error on 2017-01-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2017-01-31 00:00:00+00:00] of type Timestamp
# Error on 2017-02-28 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2017-02-28 00:00:00+00:00] of type Timestamp
# Error on 2017-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2017-03-31 00:00:00+00:00] of type Timestamp
# Error on 2017-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2017-04-30 00:00:00+00:00] of type Timestamp
# Error on 2017-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2017-05-31 00:00:00+00:00] of type Timestamp
# Error on 2017-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2017-06-30 00:00:00+00:00] of type Timestamp
# Error on 2017-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2017-07-31 00:00:00+00:00] of type Timestamp
# Error on 2017-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2017-08-31 00:00:00+00:00] of type Timestamp
# Error on 2017-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2017-09-30 00:00:00+00:00] of type Timestamp
# Error on 2017-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2017-10-31 00:00:00+00:00] of type Timestamp
# Error on 2017-11-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2017-11-30 00:00:00+00:00] of type Timestamp
# Error on 2017-12-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2017-12-31 00:00:00+00:00] of type Timestamp
# Error on 2018-01-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2018-01-31 00:00:00+00:00] of type Timestamp
# Error on 2018-02-28 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2018-02-28 00:00:00+00:00] of type Timestamp
# Error on 2018-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2018-03-31 00:00:00+00:00] of type Timestamp
# Error on 2018-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2018-04-30 00:00:00+00:00] of type Timestamp
# Error on 2018-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2018-05-31 00:00:00+00:00] of type Timestamp
# Error on 2018-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2018-06-30 00:00:00+00:00] of type Timestamp
# Error on 2018-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2018-07-31 00:00:00+00:00] of type Timestamp
# Error on 2018-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2018-08-31 00:00:00+00:00] of type Timestamp
# Error on 2018-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2018-09-30 00:00:00+00:00] of type Timestamp
# Error on 2018-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2018-10-31 00:00:00+00:00] of type Timestamp
# Error on 2018-11-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2018-11-30 00:00:00+00:00] of type Timestamp
# Error on 2018-12-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2018-12-31 00:00:00+00:00] of type Timestamp
# Error on 2019-01-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2019-01-31 00:00:00+00:00] of type Timestamp
# Error on 2019-02-28 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2019-02-28 00:00:00+00:00] of type Timestamp
# Error on 2019-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2019-03-31 00:00:00+00:00] of type Timestamp
# Error on 2019-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2019-04-30 00:00:00+00:00] of type Timestamp
# Error on 2019-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2019-05-31 00:00:00+00:00] of type Timestamp
# Error on 2019-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2019-06-30 00:00:00+00:00] of type Timestamp
# Error on 2019-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2019-07-31 00:00:00+00:00] of type Timestamp
# Error on 2019-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2019-08-31 00:00:00+00:00] of type Timestamp
# Error on 2019-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2019-09-30 00:00:00+00:00] of type Timestamp
# Error on 2019-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2019-10-31 00:00:00+00:00] of type Timestamp
# Error on 2019-11-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2019-11-30 00:00:00+00:00] of type Timestamp
# Error on 2019-12-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2019-12-31 00:00:00+00:00] of type Timestamp
# Error on 2020-01-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2020-01-31 00:00:00+00:00] of type Timestamp
# Error on 2020-02-29 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2020-02-29 00:00:00+00:00] of type Timestamp
# Error on 2020-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2020-03-31 00:00:00+00:00] of type Timestamp
# Error on 2020-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2020-04-30 00:00:00+00:00] of type Timestamp
# Error on 2020-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2020-05-31 00:00:00+00:00] of type Timestamp
# Error on 2020-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2020-06-30 00:00:00+00:00] of type Timestamp
# Error on 2020-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2020-07-31 00:00:00+00:00] of type Timestamp
# Error on 2020-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2020-08-31 00:00:00+00:00] of type Timestamp
# Error on 2020-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2020-09-30 00:00:00+00:00] of type Timestamp
# Error on 2020-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2020-10-31 00:00:00+00:00] of type Timestamp
# Error on 2020-11-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2020-11-30 00:00:00+00:00] of type Timestamp
# Error on 2020-12-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2020-12-31 00:00:00+00:00] of type Timestamp
# Error on 2021-01-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2021-01-31 00:00:00+00:00] of type Timestamp
# Error on 2021-02-28 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2021-02-28 00:00:00+00:00] of type Timestamp
# Error on 2021-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2021-03-31 00:00:00+00:00] of type Timestamp
# Error on 2021-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2021-04-30 00:00:00+00:00] of type Timestamp
# Error on 2021-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2021-05-31 00:00:00+00:00] of type Timestamp
# Error on 2021-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2021-06-30 00:00:00+00:00] of type Timestamp
# Error on 2021-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2021-07-31 00:00:00+00:00] of type Timestamp
# Error on 2021-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2021-08-31 00:00:00+00:00] of type Timestamp
# Error on 2021-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2021-09-30 00:00:00+00:00] of type Timestamp
# Error on 2021-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2021-10-31 00:00:00+00:00] of type Timestamp
# Error on 2021-11-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2021-11-30 00:00:00+00:00] of type Timestamp
# Error on 2021-12-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2021-12-31 00:00:00+00:00] of type Timestamp
# Error on 2022-01-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2022-01-31 00:00:00+00:00] of type Timestamp
# Error on 2022-02-28 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2022-02-28 00:00:00+00:00] of type Timestamp
# Error on 2022-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2022-03-31 00:00:00+00:00] of type Timestamp
# Error on 2022-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2022-04-30 00:00:00+00:00] of type Timestamp
# Error on 2022-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2022-05-31 00:00:00+00:00] of type Timestamp
# Error on 2022-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2022-06-30 00:00:00+00:00] of type Timestamp
# Error on 2022-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2022-07-31 00:00:00+00:00] of type Timestamp
# Error on 2022-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2022-08-31 00:00:00+00:00] of type Timestamp
# Error on 2022-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2022-09-30 00:00:00+00:00] of type Timestamp
# Error on 2022-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2022-10-31 00:00:00+00:00] of type Timestamp
# Error on 2022-11-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2022-11-30 00:00:00+00:00] of type Timestamp
# Error on 2022-12-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2022-12-31 00:00:00+00:00] of type Timestamp
# Error on 2023-01-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2023-01-31 00:00:00+00:00] of type Timestamp
# Error on 2023-02-28 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2023-02-28 00:00:00+00:00] of type Timestamp
# Error on 2023-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2023-03-31 00:00:00+00:00] of type Timestamp
# Error on 2023-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2023-04-30 00:00:00+00:00] of type Timestamp
# Error on 2023-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2023-05-31 00:00:00+00:00] of type Timestamp
# Error on 2023-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2023-06-30 00:00:00+00:00] of type Timestamp
# Error on 2023-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2023-07-31 00:00:00+00:00] of type Timestamp
# Error on 2023-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2023-08-31 00:00:00+00:00] of type Timestamp
# Error on 2023-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2023-09-30 00:00:00+00:00] of type Timestamp
# Error on 2023-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2023-10-31 00:00:00+00:00] of type Timestamp
# Error on 2023-11-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2023-11-30 00:00:00+00:00] of type Timestamp
# Error on 2023-12-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2023-12-31 00:00:00+00:00] of type Timestamp
# Error on 2024-01-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2024-01-31 00:00:00+00:00] of type Timestamp
# Error on 2024-02-29 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2024-02-29 00:00:00+00:00] of type Timestamp
# Error on 2024-03-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2024-03-31 00:00:00+00:00] of type Timestamp
# Error on 2024-04-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2024-04-30 00:00:00+00:00] of type Timestamp
# Error on 2024-05-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2024-05-31 00:00:00+00:00] of type Timestamp
# Error on 2024-06-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2024-06-30 00:00:00+00:00] of type Timestamp
# Error on 2024-07-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2024-07-31 00:00:00+00:00] of type Timestamp
# Error on 2024-08-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2024-08-31 00:00:00+00:00] of type Timestamp
# Error on 2024-09-30 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2024-09-30 00:00:00+00:00] of type Timestamp
# Error on 2024-10-31 00:00:00+00:00: cannot do positional indexing on DatetimeIndex with these indexers [2024-10-31 00:00:00+00:00] of type Timestamp
# Strategy Sharpe Ratio (Dynamic Multi-Factor): nan
# Benchmark Sharpe Ratio: -85.21
# Strategy Max Drawdown (Dynamic Multi-Factor): -100.00%
# Benchmark Max Drawdown: -102.44%
# Strategy Annualized Return (Dynamic Multi-Factor): -100.00%
# Benchmark Annualized Return: -100.00%
