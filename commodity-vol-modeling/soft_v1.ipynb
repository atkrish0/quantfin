# %%
import pandas as pd

# %% [markdown]
# ### Import data

# %%
file_path = 'CMO-Historical-Data-Monthly (1).xlsx'
df = pd.read_excel(file_path, sheet_name= 'Monthly Prices', skiprows=4)

# %%
df
# Out:
#     Unnamed: 0 Crude oil, average Crude oil, Brent Crude oil, Dubai  \
# 0          NaN            ($/bbl)          ($/bbl)          ($/bbl)
# 1      1960M01               1.63             1.63             1.63
# 2      1960M02               1.63             1.63             1.63
# 3      1960M03               1.63             1.63             1.63
# 4      1960M04               1.63             1.63             1.63
# ..         ...                ...              ...              ...
# 771    2024M03          83.545667           85.447             84.7
# 772    2024M04          88.011333           90.054            89.39
# 773    2024M05             81.445           81.995            83.53
# 774    2024M06             81.205           82.555            82.17
# 775    2024M07          83.258667           85.296            83.94
#
#     Crude oil, WTI Coal, Australian Coal, South African ** Natural gas, US  \
# ...

# %% [markdown]
# ### Process raw commodity data
